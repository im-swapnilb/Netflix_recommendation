# %% [markdown]
# # **Recommendation System**
# Recommendation Systems are the systems that predict and filter the future preferences of user based based on their past experience. They are widely to recommend
# * similar products (Amazon, Flipkart)
# * relevant media, e.g. photos, videos and stories (Instagram)
# * relevant series and movies (Netflix, Amazon Prime Video, Hotstar)
# * relevant songs and podcasts (Spotify)
# * relevant videos (YouTube)
# * similar users, posts (LinkedIn, Twitter, Instagram)
# * relevant dishes and restaurants (Uber Eats, Zomato, Swiggy)
#
# There are mainly 2 types of Recommendation System
# 1. Content Based RS
# 1. Collaborative Filtering
# ![](https://user-images.githubusercontent.com/43712046/69491476-766eb100-0e5b-11ea-8fa7-6bfc781045a8.png)

# %% [markdown]
# # **Content Based Recommendation Systems**
# There are cases when the user is new on a platform and we end up having no prior information on the user. In such scenerios, we recommend similar items based on comments, feedbacks, reviews, description of the items with which the user interacts.
#
# Models/ Algorithms like TF-IDF score, word2vec are used to capture the similarty in Content Based RS.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

from nltk.corpus import stopwords
from string import punctuation

import nltk as nltk
from nltk.tokenize import word_tokenize

import string


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## **Loading the Dataset**

# %%
df_netflix = pd.read_csv("netflix_titles.csv")
print (df_netflix.shape)
df_netflix.head()
# Out:
# (7787, 12)
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# # ## **Analyses of TV Shows v/s Movies**

# %%
plt.figure(figsize=(10,7))
sns.set(style="darkgrid")
ax = sns.countplot(x="type", data=df_netflix, palette="Set2")

# %%
plt.figure(figsize=(10,7))
sns.set(style="darkgrid")
ax = sns.countplot(x="date_added", data=df_netflix, palette="Set2")

# %% [markdown]
# ## **County wise analysis**

# %%
import itertools
list_country = [x.split(', ') for x in df_netflix.dropna(subset=['country'])['country'].tolist()]
list_country = list(itertools.chain(*list_country))

from collections import Counter
df_netflix_country_count = pd.DataFrame(Counter(list_country).most_common()[:10], columns=['Country', 'Count'])

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.barplot(y="Country", x='Count', data=df_netflix_country_count, palette="Set2", orient='h')

# %% [markdown]
# ## **Year wise analysis**

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y='release_year', data=df_netflix, palette="Set2", order=df_netflix['release_year'].value_counts().index[0:15])

# %%
# most release happed in netflix over a time
plt.figure(figsize=(10,8))
sns.distplot(df_netflix['release_year']);

# %%
sns.relplot(x="type", y="release_year", hue="country",data=df_netflix[:100]);

# %% [markdown]
# ## **Preprocessing of the data for RS**

# %% [markdown]
# ### **Retaining only Relevant Columns**

# %%
df_netflix.drop(columns=['director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'type'], inplace=True)
df_netflix.head()
# Out:
#   show_id  title                                          listed_in  \
# 0      s1     3%  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1      s2   7:19                       Dramas, International Movies
# 2      s3  23:59                Horror Movies, International Movies
# 3      s4      9  Action & Adventure, Independent Movies, Sci-Fi...
# 4      s5     21                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# ### **Removing Punctuations and Stopwords**

# %%
import nltk as nltk
from nltk.tokenize import word_tokenize

df_netflix['title_list'] = df_netflix['title'].str.lower()
df_netflix['listed_in'] = df_netflix['listed_in'].str.lower()
df_netflix['description'] = df_netflix['description'].str.lower()

df_netflix['title_list'] = df_netflix['title_list'].apply(word_tokenize)
df_netflix['listed_in'] = df_netflix['listed_in'].apply(word_tokenize)
df_netflix['description'] = df_netflix['description'].apply(word_tokenize)

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
from string import punctuation

list_stopwords = set(stopwords.words('english') + list(punctuation))
df_netflix['title_list'] = df_netflix['title_list'].apply(lambda x: [word for word in x if word not in list_stopwords])
df_netflix['listed_in'] = df_netflix['listed_in'].apply(lambda x: [word for word in x if word not in list_stopwords])
df_netflix['description'] = df_netflix['description'].apply(lambda x: [word for word in x if word not in list_stopwords])

# %%
import string

df_netflix['description'] = df_netflix['description'].apply(lambda x : [word.translate(str.maketrans('', '', string.punctuation)) for word in x])
df_netflix['description'] = df_netflix['description'].apply(lambda x : [word for word in x if len(word) > 0])

# %%
df_netflix['title_list'] = df_netflix['title_list'].apply(lambda x : list(set(x)))
df_netflix['listed_in'] = df_netflix['listed_in'].apply(lambda x : list(set(x)))
df_netflix['description'] = df_netflix['description'].apply(lambda x : list(set(x)))

# %%
from wordcloud import WordCloud

list_genre = df_netflix['listed_in'].tolist()
list_genre = list(itertools.chain(*list_genre))
genre = ' '.join(list_genre)

plt.figure(figsize=(16,12))
wordcloud = WordCloud(max_font_size=50, max_words=100,background_color="white").generate(genre)
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
## **WordCloud for Description**

# %%
list_description = df_netflix['description'].tolist()
list_description = list(itertools.chain(*list_description))
description = ' '.join(list_description)

plt.figure(figsize=(16,12))
wordcloud = WordCloud(max_font_size=50, max_words=100,background_color="white").generate(description)
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import gensim.downloader as api
path = api.load("word2vec-google-news-300", return_path=True)
print(path)
# Out:
#   File "<ipython-input-113-36d19bc39da0>", line 8
#     gunzip C:\Users\sbandgar/gensim-data\word2vec-google-news-300\word2vec-google-news-300.gz
#            ^
# SyntaxError: invalid syntax

# %%
import tarfile
my_tar = tarfile.open('word2vec-google-news-300.gz')
my_tar.extractall('./my_folder') # specify which folder to extract to
my_tar.close()
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# <ipython-input-115-e526143daee5> in <module>
#       1 import tarfile
# ----> 2 my_tar = tarfile.open('word2vec-google-news-300.gz')
#       3 my_tar.extractall('./my_folder') # specify which folder to extract to
#       4 my_tar.close()
#
# ~\Anaconda3\lib\tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1602                         fileobj.seek(saved_pos)
#    1603                     continue
# -> 1604             raise ReadError("file could not be opened successfully")
#    1605
#    1606         elif ":" in mode:
#
# ReadError: file could not be opened successfully

# %%
# !gunzip C:\Users\sbandgar/gensim-data\word2vec-google-news-300\word2vec-google-news-300.gz
# Out:
# 'gunzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import gensim

wv = gensim.models.KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin", binary=True)

# %%
matrix_netflix_vocab = []
for list_ in df_netflix.to_numpy():
    list_[2] = [word for word in list_[2] if word in wv.vocab]
    list_[3] = [word for word in list_[3] if word in wv.vocab]
    list_[4] = [word for word in list_[4] if word in wv.vocab]
    matrix_netflix_vocab.append(list_)
df_netflix_vocab = pd.DataFrame(matrix_netflix_vocab, columns=df_netflix.columns)

# %%
from tqdm import tqdm

def recommendation(title):
    matrix_netflix_title_vocab = []
    for list_ in df_netflix[df_netflix['title'] == title].to_numpy():
        list_[2] = [word for word in list_[2] if word in wv.vocab]
        list_[3] = [word for word in list_[3] if word in wv.vocab]
        list_[4] = [word for word in list_[4] if word in wv.vocab]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(matrix_netflix_vocab)
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:
            score_catg = wv.n_similarity(list1[2], list2[2])
            score_desc = wv.n_similarity(list1[3], list2[3])
            try:
                score_title = wv.n_similarity(list1[4], list2[4])/2
            except:
                score_title = 0
            if ((list1[1] != list2[1]) & (score_catg > 0.85)):
                matrix_similarity.append([list1[1], list2[1], score_title, score_catg, score_desc])
        pbar.update()
    pbar.close()
    df_netflix_similarity = pd.DataFrame(matrix_similarity, columns = ['recommendation','title','score_title', 'score_category', 'score_description'])
    df_netflix_similarity['final_score'] = df_netflix_similarity['score_title'] + df_netflix_similarity['score_category'] + df_netflix_similarity['score_description']
    return (df_netflix_similarity.sort_values(by=['final_score', 'score_category', 'score_description', 'score_title'], ascending=False).head(10))

# %%
recommendation('Avengers: Infinity War')
# Out:
# 100%|██████████| 7787/7787 [00:03<00:00, 2042.28it/s]
#                          recommendation                   title  score_title  \
# 123                         Planet Hulk  Avengers: Infinity War     0.170187
# 45                   Doom: Annihilation  Avengers: Infinity War     0.210455
# 162                Terminator Salvation  Avengers: Infinity War     0.214154
# 114                          Occupation  Avengers: Infinity War     0.172816
# 116       Oh No! It's an Alien Invasion  Avengers: Infinity War     0.283219
# 74                             Hulk Vs.  Avengers: Infinity War     0.118704
# 166                     The Book of Eli  Avengers: Infinity War     0.131509
# 161  Terminator 3: Rise of the Machines  Avengers: Infinity War     0.184206
# 12                        Alien Warfare  Avengers: Infinity War     0.265108
# 138      Scorpion King 5: Book of Souls  Avengers: Infinity War     0.197633
#
#      score_category  score_description  final_score
# 123        1.000000           0.691321     1.861508
# 45         0.883960           0.699530     1.793944
# 162        1.000000           0.555739     1.769893
# 114        1.000000           0.583606     1.756422
# 116        0.860369           0.605134     1.748722
# 74         1.000000           0.628452     1.747156
# 166        1.000000           0.614370     1.745879
# 161        1.000000           0.559653     1.743859
# 12         1.000000           0.458889     1.723997
# 138        1.000000           0.516952     1.714585

# %%
recommendation('Black Panther')
# Out:
# 100%|██████████| 7787/7787 [00:02<00:00, 3753.67it/s]
#                               recommendation          title  score_title  \
# 35                       Clash of the Titans  Black Panther     0.047077
# 67                   Halo: The Fall of Reach  Black Panther     0.052581
# 33                                   Chappie  Black Panther     0.112706
# 79                  Illang: The Wolf Brigade  Black Panther     0.219760
# 107                             Men in Black  Black Panther     0.297452
# 38                  DC's Legends of Tomorrow  Black Panther     0.086030
# 158                         Superman Returns  Black Panther     0.090467
# 140                      Season of the Witch  Black Panther     0.126985
# 86                         Jupiter Ascending  Black Panther     0.083517
# 106  Marvel's Iron Man & Hulk: Heroes United  Black Panther     0.136722
#
#      score_category  score_description  final_score
# 35         1.000000           0.674041     1.721117
# 67         1.000000           0.655358     1.707939
# 33         1.000000           0.579021     1.691727
# 79         0.902778           0.566434     1.688972
# 107        0.885755           0.503077     1.686284
# 38         0.909350           0.689813     1.685193
# 158        1.000000           0.593951     1.684417
# 140        1.000000           0.556901     1.683886
# 86         1.000000           0.598604     1.682121
# 106        1.000000           0.539501     1.676223

# %%
recommendation('Friends')
# Out:
# 100%|██████████| 7787/7787 [00:01<00:00, 4008.13it/s]
#             recommendation    title  score_title  score_category  \
# 29             Girlfriends  Friends     0.306857        0.853450
# 86         Toast of London  Friends     0.112076        0.924088
# 21                Episodes  Friends     0.040227        1.000000
# 18              Dad's Army  Friends     0.177361        0.924088
# 10               Big Mouth  Friends     0.085473        0.853450
# 61                Real Rob  Friends     0.090192        0.853450
# 38               I'm Sorry  Friends     0.123332        0.853450
# 23         F is for Family  Friends     0.199680        0.853450
# 74  The Andy Griffith Show  Friends     0.031710        1.000000
# 26                 Frasier  Friends     0.000000        1.000000
#
#     score_description  final_score
# 29           0.651396     1.811704
# 86           0.686581     1.722745
# 21           0.644352     1.684579
# 18           0.576079     1.677529
# 10           0.722250     1.661173
# 61           0.693652     1.637294
# 38           0.657182     1.633965
# 23           0.572685     1.625816
# 74           0.590680     1.622389
# 26           0.619905     1.619905

# %%
recommendation('Transformers: Robots in Disguise')
# Out:
# 100%|██████████| 7787/7787 [00:02<00:00, 3061.90it/s]
#                        recommendation                             title  \
# 181                Transformers Prime  Transformers: Robots in Disguise
# 128         Power Rangers Ninja Steel  Transformers: Robots in Disguise
# 184         Transformers: Rescue Bots  Transformers: Robots in Disguise
# 183          Transformers: Cyberverse  Transformers: Robots in Disguise
# 132              Power Rangers S.P.D.  Transformers: Robots in Disguise
# 182  Transformers Rescue Bots Academy  Transformers: Robots in Disguise
# 127        Power Rangers Mystic Force  Transformers: Robots in Disguise
# 140          Power Rangers: Megaforce  Transformers: Robots in Disguise
# 125   Power Rangers Lightspeed Rescue  Transformers: Robots in Disguise
# 120         Power Rangers Dino Charge  Transformers: Robots in Disguise
#
#      score_title  score_category  score_description  final_score
# 181     0.259793             1.0           0.743294     2.003088
# 128     0.224441             1.0           0.715814     1.940255
# 184     0.360727             1.0           0.577564     1.938291
# 183     0.329207             1.0           0.546093     1.875300
# 132     0.129383             1.0           0.740242     1.869625
# 182     0.339783             1.0           0.524451     1.864235
# 127     0.140440             1.0           0.718094     1.858533
# 140     0.129383             1.0           0.727662     1.857044
# 125     0.191788             1.0           0.643679     1.835467
# 120     0.151468             1.0           0.669428     1.820896

# %%
recommendation("Article 15")
# Out:
# 100%|██████████| 7787/7787 [00:02<00:00, 3762.81it/s]
#                               recommendation       title  score_title  \
# 1133           Parmanu: The Story of Pokhran  Article 15     0.259827
# 792   Kalushi: The Story of Solomon Mahlangu  Article 15     0.232823
# 1335                    Sicilian Ghost Story  Article 15     0.189079
# 728                            Interrogation  Article 15     0.025696
# 1020                        My Birthday Song  Article 15     0.097087
# 1545                               The Hater  Article 15     0.105814
# 1582                       The Letter Reader  Article 15     0.275293
# 968                                    Metro  Article 15     0.055806
# 770                  Just Another Love Story  Article 15     0.170546
# 79                               Aapla Manus  Article 15     0.079929
#
#       score_category  score_description  final_score
# 1133        0.938539           0.534093     1.732458
# 792         0.938539           0.555827     1.727189
# 1335        1.000000           0.527167     1.716246
# 728         1.000000           0.678837     1.704533
# 1020        1.000000           0.592792     1.689879
# 1545        1.000000           0.577358     1.683172
# 1582        0.938539           0.447380     1.661212
# 968         1.000000           0.599458     1.655264
# 770         0.938539           0.536949     1.646035
# 79          1.000000           0.565274     1.645202

# %%
recommendation("Interrogation")
# Out:
# 100%|██████████| 7787/7787 [00:03<00:00, 2544.09it/s]
#                recommendation          title  score_title  score_category  \
# 167                Article 15  Interrogation     0.025696        1.000000
# 1326  Shootout at Lokhandwala  Interrogation     0.130438        0.857722
# 626                  Gun City  Interrogation     0.070762        1.000000
# 1248               Rogue City  Interrogation     0.045141        1.000000
# 1267        Saheb Bibi Golaam  Interrogation     0.141940        0.938539
# 1531       The Forest of Love  Interrogation     0.059584        1.000000
# 1332                  Shuddhi  Interrogation     0.000000        1.000000
# 3                      Oct-01  Interrogation     0.000000        1.000000
# 48               7 Khoon Maaf  Interrogation     0.091533        1.000000
# 1015         Mumbai Meri Jaan  Interrogation     0.104024        0.938539
#
#       score_description  final_score
# 167            0.678837     1.704533
# 1326           0.695054     1.683214
# 626            0.604616     1.675378
# 1248           0.609174     1.654316
# 1267           0.572346     1.652825
# 1531           0.588271     1.647855
# 1332           0.645972     1.645972
# 3              0.645429     1.645429
# 48             0.552510     1.644043
# 1015           0.600259     1.642822

# %%
# Out:
# 100%|██████████| 7787/7787 [00:00<00:00, 650683.24it/s]
# Empty DataFrame
# Columns: [recommendation, title, score_title, score_category, score_description, final_score]
# Index: []

# %%
recommendation("Batman")
# Out:
# 100%|██████████| 7787/7787 [00:00<00:00, 976122.09it/s]
# Empty DataFrame
# Columns: [recommendation, title, score_title, score_category, score_description, final_score]
# Index: []
